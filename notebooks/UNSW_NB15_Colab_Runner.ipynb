# %% [markdown]
# # UNSW-NB15 Experiment Runner
#
# This notebook allows you to run the UNSW-NB15 Imbalance Study experiments in Google Colab.

# %%
# 1. Setup Environment

# If using Google Drive to store the repo/data:
from google.colab import drive
drive.mount('/content/drive')

import os
# Navigate to the project folder (adjust path as needed)
# os.chdir('/content/drive/MyDrive/ML_PAPER_REVIEW')

# OR if cloning from GitHub:
# !git clone https://github.com/yourusername/ML_PAPER_REVIEW.git
# os.chdir('ML_PAPER_REVIEW')

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt
# !pip install xgboost==2.0.3  # Ensure recent XGBoost

# %%
# 3. Verify Data
# Ensure dataset files are present
# !ls -l dataset/

# %%
# 4. Run Visualization Demo (Fast)
# Runs a subset of experiments and generates learning curves
# !python -m scripts.run_visualization_demo

# %%
# 5. View Generated Figures
import glob
from IPython.display import Image, display

figures = glob.glob('results_viz_demo/figures/*.png')
for fig in figures:
    display(Image(filename=fig))

# %%
# 6. Run Full Experiment Grid (Slow)
# !python main.py
